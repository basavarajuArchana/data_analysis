# %% [markdown]
# # Web scrapping
#
# 1. requests : This is used to extract the HTML Code from the given URL
# 2. BeautifulSoup : format and scarp the data from the HTML
#
#
# # Steps
#
# 1. Identify URL
# 2. Inspect HTML code
# 3. find the HTML code tag for the element that you want to extract
# 4. write some code to scrap this data

# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup

# %%
# Identify URL
url='https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %%
# loading the webpage in memory using requests library
page=requests.get(url)

# %%
#check the status code of page
page.status_code
# Out:
# 200

# %%
htmlCode=page.text

# %%
htmlCode
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.6c22a8.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/ap
# ...

# %% [markdown]
# Identify
#
# Product name,
# price,
# rating,
# title,
# feature,
# Rating

# %% [markdown]
# # Format HTML Code using bs4 library

# %%
soup=BeautifulSoup(htmlCode)

# %%
help(soup)
# Out:
# Help on BeautifulSoup in module bs4 object:
#
# class BeautifulSoup(bs4.element.Tag)
#  |  BeautifulSoup(markup='', features=None, builder=None, parse_only=None, from_encoding=None, exclude_encodings=None, element_classes=None, **kwargs)
#  |
#  |  A data structure representing a parsed HTML or XML document.
#  |
#  |  Most of the methods you'll call on a BeautifulSoup object are inherited from
#  |  PageElement or Tag.
#  |
#  |  Internally, this class defines the basic interface called by the
#  |  tree builders when converting an HTML/XML document into a data
#  |  structure. The interface abstracts away the differences between
#  |  parsers. To write a new tree builder, you'll need to understand
#  |  these methods as a whole.
#  |
#  |  These methods will be called by the BeautifulSoup constructor:
#  |    * reset()
#  |    * feed(markup)
#  |
#  |  The tree builder may call these methods from its feed() implementation:
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.6c22a8.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %% [markdown]
# Product Name : _4rR01T
#
# Price :  _30jeq3 _1_WHN1
#
# Rating : gUuXy-
#
# Specification : fMghEO

# %% [markdown]
# # find()

# %%
product_name=soup.find('div',attrs={'class':'_4rR01T'})
print(product_name.text)
# Out:
# MSI Creator Z16 Core i9 11th Gen - (16 GB/1 TB SSD/Windows 10 Home/6 GB Graphics/NVIDIA GeForce RTX 30...

# %%
price=soup.find('div',attrs={'class':'_30jeq3 _1_WHN1'})
print(price.text)
# Out:
# ₹1,92,990

# %%
rating=soup.find('div',attrs={'class':'gUuXy-'})
print(rating.text)
# Out:
# 4.4573 Ratings & 71 Reviews

# %%
feature_list=soup.find('div',attrs={'class':'fMghEO'})
print(feature_list.text)
# Out:
# Intel Core i9 Processor (11th Gen)16 GB DDR4 RAM64 bit Windows 10 Operating System1 TB SSD40.64 cm (16 inch) Display2 Year Carry-In Warranty

# %% [markdown]
# # find_all()

# %%
# find all product name
products_name=soup.find_all('div',attrs={'class':'_4rR01T'})
for i in range(0,len(products_name)):
    print(products_name[i].text)
# Out:
# MSI Creator Z16 Core i9 11th Gen - (16 GB/1 TB SSD/Windows 10 Home/6 GB Graphics/NVIDIA GeForce RTX 30...
# DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 11 Home) Inspiron 3511 Thin and Lig...
# ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS Thin and L...
# ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce G...
# Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 GB SSD/Windows 11 Home) 15ITL6 Thin and Light Laptop
# ASUS Ryzen 3 Dual Core 3250U 3rd Gen - (8 GB/256 GB SSD/Windows 10 Home) M515DA-BQ322TS Thin and Light...
# Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 11 Home) 14IML05 Thin and Light Laptop
# HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) 15s-dy3501TU Thin and Light Laptop
# acer Aspire 7 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 165...
# ...

# %%
# find all product price
products_price=soup.find_all('div',attrs={'class':'_30jeq3 _1_WHN1'})
for i in range(0,len(products_price)):
    print(products_price[i].text)
# Out:
# ₹1,92,990
# ₹45,490
# ₹37,990
# ₹57,990
# ₹40,990
# ₹35,990
# ₹38,990
# ₹42,990
# ₹52,990
# ₹43,990
# ₹37,925
# ₹37,990
# ₹54,490
# ₹48,990
# ₹37,790
# ₹42,990
# ₹40,990
# ₹37,490
# ₹54,990
# ₹41,990
# ₹41,790
# ₹42,990
# ₹37,490
# ₹29,990

# %%
# Scrapping the Web Page

title = []
rating = []
price = []
features = []

for i in range(1, 39):
    URL = 'https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off={}'. format(i)
    
    page = requests.get(URL)
    htmlCode = page.text
    
    soup = BeautifulSoup(htmlCode)
    
    for x in soup.find_all('div', attrs={'class' : '_2kHMtA'}):

        product = x.find('div', attrs={'class' : '_4rR01T'})
        if product is None:
            title.append(np.NaN)
        else:
            title.append(product.text)

        mrp = x.find('div', attrs={'class' : '_30jeq3 _1_WHN1'})
        if mrp is None:
            price.append(np.NaN)
        else:
            price.append(mrp.text)

        rate = x.find('div', attrs={'class' : '_3LWZlK'})
        if rate is None:
            rating.append(np.NaN)
        else:
            rating.append(rate.text)

        f = x.find('ul', attrs={'class' : '_1xgFaf'})
        if f is None:
            features.append(np.NaN)
        else:
            features.append(f.text)

# %%
print(len(title))
print(len(price))
print(len(rating))
print(len(features))
# Out:
# 888
# 888
# 888
# 888

# %%
df = pd.DataFrame({'Product' : title, 'Rating' : rating, 'MRP' : price, 'Feature' : features})

# %%
df.head()
# Out:
#                                              Product Rating        MRP  \
# 0  MSI Creator Z16 Core i9 11th Gen - (16 GB/1 TB...    NaN  ₹1,92,990
# 1  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...    4.4    ₹45,490
# 2  ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...    4.3    ₹37,990
# 3  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...    4.5    ₹57,990
# 4  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...    4.3    ₹40,990
#
#                                              Feature
# 0  Intel Core i9 Processor (11th Gen)16 GB DDR4 R...
# 1  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...
# 4  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...

# %%
# exporting to file
df.to_csv('D:/git hub/laptop_details.csv', index=False)

# %%
# Display data
df1=pd.read_csv('D:/git hub/laptop_details.csv')
df1.head()
# Out:
#                                              Product  Rating        MRP  \
# 0  MSI Creator Z16 Core i9 11th Gen - (16 GB/1 TB...     NaN  ₹1,92,990
# 1  DELL Inspiron Core i3 11th Gen - (8 GB/1 TB HD...     4.4    ₹45,490
# 2  ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...     4.3    ₹37,990
# 3  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...     4.5    ₹57,990
# 4  Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/256 ...     4.3    ₹40,990
#
#                                              Feature
# 0  Intel Core i9 Processor (11th Gen)16 GB DDR4 R...
# 1  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
# 2  Intel Core i3 Processor (10th Gen)8 GB DDR4 RA...
# 3  Intel Core i5 Processor (10th Gen)8 GB DDR4 RA...
# 4  Intel Core i3 Processor (11th Gen)8 GB DDR4 RA...
